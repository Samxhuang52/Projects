# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import seaborn as sns
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('MergedWithDays.csv')
# Out:
# /Users/Singsing/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  SecondsViewed_x           CompPrimaryKey           Programme  \
# 0           0              898  along-for-the-ride10321  along-for-the-ride
# 1           1             1711  along-for-the-ride10472  along-for-the-ride
# 2           2             3798  along-for-the-ride10570  along-for-the-ride
# 3           3             1289  along-for-the-ride10639  along-for-the-ride
# 4           4             3427  along-for-the-ride10738  along-for-the-ride
#
#    New.Cust.ID  Gender  AgeRange Week.of.Programme.Viewing  \
# 0        10321  female  25 to 34                    6/7/15
# 1        10472    male  35 to 44                   2/15/15
# 2        10570    male  65 to 74                    3/1/15
# 3        10639  female  55 to 64                    3/8/15
# 4        10738  female  45 to 54                   3/22/15
#
#             VideoGenre    star           ...             4  5  6  7  \
# 0  factual,new-zealand  108707           ...             0  0  0  1
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  SecondsViewed_x   New.Cust.ID  sum_secondviewed  \
# count  68580.000000     68580.000000  68580.000000      68580.000000
# mean   34289.500000      6276.538976  22367.224628   14375572.870604
# std    19797.485068      8115.134979  12854.009001    9052128.826173
# min        0.000000         1.000000      2.000000      38641.000000
# 25%    17144.750000      1209.000000  11409.000000    7159899.000000
# 50%    34289.500000      3068.000000  22286.000000   13897073.000000
# 75%    51434.250000      8293.250000  33474.000000   22268781.000000
# max    68579.000000    273235.000000  44808.000000   29963295.000000
#
#        dirctor.ranking  producer.ranking  actor1.ranking     actor1 BS  \
# count     68580.000000      68580.000000    68580.000000  68580.000000
# mean      58580.623870     217856.229105     2864.689458      5.541980
# std       82221.471654     487294.766948     5901.494792      8.210855
# ...

# %%
actor1=pd.DataFrame()
actor1['actor']= df['actor1']
actor1['actorBS']=df['actor1 BS']

# %%
actor2=pd.DataFrame()
actor2['actor']= df['actor2']
actor2['actorBS']=df['actor2 BS']

# %%
actor3=pd.DataFrame()
actor3['actor']=df['actor3']
actor3['actorBS']=df['actor3 BS']

# %%
actor123 = pd.concat([actor1,actor2,actor3],axis=0)

# %%
actor123 = actor123.drop_duplicates()

# %%
actor123.describe()
# Out:
#           actorBS
# count  167.000000
# mean     5.089820
# std      9.901823
# min    -48.000000
# 25%     -1.000000
# 50%      4.000000
# 75%     11.000000
# max     35.000000

# %%
actor123.min()
# Out:
# actor      Aimee Carrero
# actorBS              -48
# dtype: object

# %%
actor123.to_excel('actor123.xlsx')

# %%
actor123
# Out:
#                     actor  actorBS
# 0       Randall Batinkoff        7
# 310          Tom Bergeron       14
# 659         Shawnee Smith       11
# 1092        Stephen Amell       -3
# 3529    Jean-Luc Bilodeau       -6
# 4680          Dana Delany       27
# 4718    Anthony McPartlin        3
# 7400        David Tennant        2
# 9875       Nathan Fillion        0
# 11924        Shemar Moore        5
# 14907       Ashley Jensen       16
# 14933     Terrence Howard       15
# 17426       Ioan Gruffudd        0
# 19962      Brian Drummond       16
# 21653          Theo James       -7
# 21883        Ben McKenzie       -2
# 23356         Eliza Coupe        0
# 23633       Rachel Bilson        4
# 24788  Valerie Bertinelli       24
# 25244          Ted Danson        2
# 25417       Suranne Jones       11
# 25434      Patrick Wilson        4
# 25570      Mary McDonnell       24
# 26616           Ayla Kell       -2
# 26714       Hayley Atwell        2
# 28202         Clark Gregg       -3
# ...

# %%
plt.hist(actor123['actorBS'])
# Out:
# (array([  1.,   0.,   0.,   0.,  12.,  42.,  69.,  29.,   9.,   5.]),
#  array([-48. , -39.7, -31.4, -23.1, -14.8,  -6.5,   1.8,  10.1,  18.4,
#          26.7,  35. ]),
#  <a list of 10 Patch objects>)
